# %% [markdown]
# ### 斐波那契通道斐波那契通道是基于斐波那契数列的技术分析工具，用于识别潜在的支撑和阻力水平。它由三条线组成，分别是斐波那契回撤线、斐波那契扩展线和斐波那契通道线。这些线根据斐波那契数列的比例计算得出，常用的比例包括0.382、0.5、0.618等。
# ##### 斐波那契回撤线是从一个重要的价格高点到一个重要的价格低点之间绘制的水平线，用于识别潜在的支撑和阻力水平。
# ##### 斐波那契扩展线是从一个重要的价格低点到一个重要的价格高点之间绘制的水平线，用于识别潜在的目标价格水平。
# ##### 斐波那契通道线是根据斐波那契数列的比例计算得出的两条平行线，用于识别潜在的趋势通道。
# 斐波那契通道可以帮助交易者识别潜在的价格反转点和趋势延续点，从而制定更有效的交易策略。然而，斐波那契通道并不是一种独立的交易工具，通常需要与其他技术分析工具结合使用，以提高其准确性和可靠性。

# %%
def f
